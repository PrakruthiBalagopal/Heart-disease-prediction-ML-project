# %% [markdown]
# # Building a simple neural network

# %%
from keras.models import Sequential                                #importing the required libraries
from keras.layers import Dense
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
df=pd.read_csv("C:/Users/91866/OneDrive/Desktop/ML LAB/Disease prediction ML project/heart disease dataset.csv")
df.head()
#reading the data
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
#splitting the data
from sklearn.model_selection import train_test_split

predictors = df.drop("target",axis=1)
target = df["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (952, 11)

# %%
X_test.shape
# Out:
# (238, 11)

# %%
Y_train.shape
# Out:
# (952,)

# %%
Y_test.shape
# Out:
# (238,)

# %%
#craeting and compiling the neural network model
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=11))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#fitting the model with the data
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3808 - accuracy: 0.8382
# Epoch 2/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8225
# Epoch 3/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8456
# Epoch 4/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8235
# Epoch 5/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3905 - accuracy: 0.8372
# Epoch 6/300
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8372
# Epoch 7/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8277
# Epoch 8/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8288
# Epoch 9/300
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8351
# Epoch 10/300
# ...

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
Y_pred_nn.shape
# Out:
# (238, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
#calculating the accuracy of the neural network model
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")
# Out:
# The accuracy score achieved using Neural Network is: 78.99 %
